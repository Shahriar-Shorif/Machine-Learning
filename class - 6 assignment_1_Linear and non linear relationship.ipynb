# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv('linear_data.csv')
df.head()
# Out:
#          x         y
# 0  0.00000  4.447692
# 1  0.02004  5.024612
# 2  0.04008  5.869593
# 3  0.06012  4.722490
# 4  0.08016  4.877101

# %%
df.corr()
# Out:
#          x        y
# x  1.00000  0.99644
# y  0.99644  1.00000

# %%
plt.scatter(df['x'], df['y'],label='Data points', color='red')
plt.xlabel('X ')
plt.ylabel('Y ')
# Out:
# Text(0, 0.5, 'Y ')

# %%
reg1 = LinearRegression()
df.head()
reg1.fit(df[['x']],df[['y']])
# Out:
# LinearRegression()

# %%
reg1.score(df[['x']],df[['y']])
# Out:
# 0.9928923730526016

# %%
df2 = pd.read_csv('nonlinear_data.csv')

# %%
df2.head()
# Out:
#          x         y
# 0  0.00000 -0.155043
# 1  0.02004  0.081809
# 2  0.04008 -0.014298
# 3  0.06012  0.143978
# 4  0.08016  0.019553

# %%
x = df2[['x']]
y = df2['y']

# %%
df2.corr()
# Out:
#           x         y
# x  1.000000 -0.065736
# y -0.065736  1.000000

# %%
plt.scatter(x,y)

# %%
reg2 = LinearRegression()

# %%
reg2.fit(x,y)
# Out:
# LinearRegression()

# %%
reg2.score(x,y)
# Out:
# 0.004321199719043656

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=6)      # polynomial regression with degree n
X_poly = poly.fit_transform(df2[['x']])

# %%
X_poly.shape
# Out:
# (500, 7)

# %%
poly_reg = LinearRegression()

# %%
 poly_reg.fit(X_poly,df2['y'])
# Out:
# LinearRegression()

# %%
poly_reg.score(X_poly,df2['y'])
# Out:
# 0.9930624844497349

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#          x         y
# 0  0.00000  4.447692
# 1  0.02004  5.024612
# 2  0.04008  5.869593
# 3  0.06012  4.722490
# 4  0.08016  4.877101

# %%
train, test = train_test_split(df,test_size = 0.25 , random_state = 1)

# %%
test.head()
test.shape
# Out:
# (125, 2)

# %%
train.head()
train.shape
# Out:
# (375, 2)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_poly,df.y, train_size = 0.75, random_state = 1)

# %%
Traintest = poly_reg.fit(xtrain,ytrain)

# %%
Traintest.score(xtrain,ytrain)
# Out:
# 0.9922246712557984

# %%
Test = poly_reg.fit(xtest,ytest)

# %%
Test.score(xtest,ytest)
# Out:
# 0.9951918322998449
